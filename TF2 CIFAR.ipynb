# %%
# !pip install -q tensorflow==2.1.0
# Out:
#      |████████████████████████████████| 421.8MB 36kB/s
#      |████████████████████████████████| 3.9MB 49.4MB/s
#      |████████████████████████████████| 450kB 50.2MB/s
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
# additional imports
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D
from tensorflow.keras.models import Model

# %%
# Load in the data
cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train/255.0, x_test/255.0
y_train, y_test = y_train.flatten(), y_test.flatten()
print("x_train.shape: ", x_train.shape)
print("y_train.shape: ", y_train.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# x_train.shape:  (50000, 32, 32, 3)
# y_train.shape:  (50000,)

# %%
# number of classes
K = len(set(y_train))
print("number of classes: ", K)
# Out:
# number of classes:  10

# %%
# Build the model using the functional API
i = Input(shape=x_train[0].shape)
x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)
x = Flatten()(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)

# %%
# Compile and fit
# Note: make sure you are using the GPU for this!
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
r = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=15)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/15
# 50000/50000 [==============================] - 47s 937us/sample - loss: 1.5866 - accuracy: 0.4209 - val_loss: 1.2653 - val_accuracy: 0.5467
# Epoch 2/15
# 50000/50000 [==============================] - 47s 931us/sample - loss: 1.2971 - accuracy: 0.5349 - val_loss: 1.1424 - val_accuracy: 0.5885
# Epoch 3/15
# 50000/50000 [==============================] - 46s 928us/sample - loss: 1.1705 - accuracy: 0.5817 - val_loss: 1.0857 - val_accuracy: 0.6132
# Epoch 4/15
# 50000/50000 [==============================] - 46s 928us/sample - loss: 1.0851 - accuracy: 0.6133 - val_loss: 1.0172 - val_accuracy: 0.6377
# Epoch 5/15
# 50000/50000 [==============================] - 46s 929us/sample - loss: 1.0232 - accuracy: 0.6357 - val_loss: 0.9892 - val_accuracy: 0.6549
# Epoch 6/15
# 50000/50000 [==============================] - 46s 928us/sample - loss: 0.9633 - accuracy: 0.6554 - val_loss: 0.9232 - val_accuracy: 0.6759
# Epoch 7/15
# 50000/50000 [==============================] - 46s 928us/sample - loss: 0.9092 - accuracy: 0.6769 - val_loss: 0.9136 - val_accuracy: 0.6802
# Epoch 8/15
# 50000/50000 [==============================] - 46s 930us/sample - loss: 0.8678 - accuracy: 0.6907 - val_loss: 0.8831 - val_accuracy: 0.6920
# Epoch 9/15
# 50000/50000 [==============================] - 46s 929us/sample - loss: 0.8286 - accuracy: 0.7054 - val_loss: 0.8807 - val_accuracy: 0.6920
# Epoch 10/15
# 50000/50000 [==============================] - 47s 932us/sample - loss: 0.7914 - accuracy: 0.7195 - val_loss: 0.8811 - val_accuracy: 0.6970
# Epoch 11/15
# 50000/50000 [==============================] - 47s 940us/sample - loss: 0.7654 - accuracy: 0.7267 - val_loss: 0.8448 - val_accuracy: 0.7097
# Epoch 12/15
# 50000/50000 [==============================] - 46s 930us/sample - loss: 0.7292 - accuracy: 0.7408 - val_loss: 0.8568 - val_accuracy: 0.7010
# Epoch 13/15
# 50000/50000 [==============================] - 48s 964us/sample - loss: 0.7033 - accuracy: 0.7484 - val_loss: 0.8573 - val_accuracy: 0.7024
# Epoch 14/15
# 50000/50000 [==============================] - 46s 929us/sample - loss: 0.6876 - accuracy: 0.7564 - val_loss: 0.8367 - val_accuracy: 0.7117
# Epoch 15/15
# 50000/50000 [==============================] - 46s 928us/sample - loss: 0.6546 - accuracy: 0.7663 - val_loss: 0.8453 - val_accuracy: 0.7026
